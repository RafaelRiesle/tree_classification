# %%
from preprocessing.preprocessing_pipeline.preprocessing_pipeline import PreprocessingPipeline

# %%
path = "../../../data/Trainings_Datensatz.csv"

pipeline = PreprocessingPipeline(
    path=path,
    basic_features=True,
    data_augmentation=False,
    calculate_indices=True,
    temporal_features=True,
    interpolate_b4=True,
    outlier_cleaner=False,
    detect_disturbed_trees=False, 
    specify_disturbed_labels=True,
)

df_cleaned = pipeline.run()

# TO DO:
# sin columns as flag
# Out:
# Confusion Matrix:
# [[1439   14]
#  [   6 1833]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1453
#            1       0.99      1.00      0.99      1839
#
#     accuracy                           0.99      3292
#    macro avg       0.99      0.99      0.99      3292
# weighted avg       0.99      0.99      0.99      3292

# %%
df_cleaned
# Out:
#                      species                          time          b2  \
# 0        Norway_spruce_mixed 2017-01-01 00:00:00.000000000         NaN
# 1        Norway_spruce_mixed 2017-01-01 00:05:00.520022328  189.576692
# 2        Norway_spruce_mixed 2017-01-01 00:10:01.040044657  189.643742
# 3        Norway_spruce_mixed 2017-01-01 00:15:01.560066985  189.710791
# 4        Norway_spruce_mixed 2017-01-01 00:20:02.080089314  189.777841
# ...                      ...                           ...         ...
# 3927087        Norway_spruce 2022-08-05 00:00:00.000000000  111.000000
# 3927088        Norway_spruce 2022-08-09 00:00:00.000000000  147.000000
# 3927089        Norway_spruce 2022-08-12 00:00:00.000000000  136.000000
# 3927090        Norway_spruce 2022-08-27 00:00:00.000000000  283.000000
# 3927091        Norway_spruce 2022-09-13 00:00:00.000000000  159.000000
#
#                  b3          b4          b5           b6           b7  \
# 0               NaN         NaN         NaN          NaN          NaN
# 1        199.840686   57.201620  279.435264  1008.396028  1392.298599
# 2        200.022986   57.413992  279.865391  1008.836766  1392.135242
# 3        200.205285   57.626363  280.295519  1009.277505  1391.971886
# 4        200.387584   57.838735  280.725647  1009.718243  1391.808530
# ...             ...         ...         ...          ...          ...
# 3927087  278.000000  138.000000  415.000000  1600.000000  1997.000000
# 3927088  269.000000  139.000000  418.000000  1512.000000  1994.000000
# 3927089  317.000000  158.000000  446.000000  1724.000000  2009.000000
# 3927090  445.000000  316.000000  606.000000  1709.000000  2019.000000
# 3927091  279.000000  175.000000  456.000000  1461.000000  1768.000000
#
#                   b8          b8a  ...       mcari        reip    masvi2  \
# 0                NaN          NaN  ...         NaN         NaN       NaN
# 1        1390.013402  1531.790083  ...         NaN         NaN       NaN
# 2        1389.537104  1531.787239  ...         NaN         NaN       NaN
# 3        1389.060806  1531.784395  ...         NaN         NaN       NaN
# 4        1388.584508  1531.781551  ...         NaN         NaN       NaN
# ...              ...          ...  ...         ...         ...       ...
# 3927087  2258.000000  2218.000000  ...  750.608696  722.025316 -0.999557
# 3927088  2208.000000  2329.000000  ...  749.392806  723.711152 -0.999547
# 3927089  2282.000000  2289.000000  ...  740.134177  719.953052 -0.999562
# 3927090  2267.000000  2297.000000  ...  494.388608  720.362647 -0.999559
# 3927091  1909.000000  2075.000000  ...  639.963429  720.517413 -0.999476
#
#             dvi  month_num    year  season  month_sin     month_cos  date_diff
# 0           NaN        NaN     NaN     NaN        NaN           NaN        NaN
# 1           NaN        NaN     NaN     NaN        NaN           NaN        NaN
# 2           NaN        NaN     NaN     NaN        NaN           NaN        NaN
# 3           NaN        NaN     NaN     NaN        NaN           NaN        NaN
# 4           NaN        NaN     NaN     NaN        NaN           NaN        NaN
# ...         ...        ...     ...     ...        ...           ...        ...
# 3927087  2120.0        8.0  2022.0  Summer  -0.866025 -5.000000e-01        1.0
# 3927088  2069.0        8.0  2022.0  Summer  -0.866025 -5.000000e-01        4.0
# 3927089  2124.0        8.0  2022.0  Summer  -0.866025 -5.000000e-01        3.0
# 3927090  1951.0        8.0  2022.0  Summer  -0.866025 -5.000000e-01       15.0
# 3927091  1734.0        9.0  2022.0  Autumn  -1.000000 -1.836970e-16       17.0
#
# [4326465 rows x 29 columns]

# %%
df_cleaned.groupby("species").size()
# Out:
# species
# Norway_spruce           617875
# Norway_spruce_mixed    1113940
# Scots_pine              915178
# beech                   217776
# disturbed               465648
# oak                      73011
# soil                    523844
# dtype: int64
